# %% [markdown]
# <a href="https://colab.research.google.com/github/joelsoaresjr/python_strategies/blob/main/grafico_opcoes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()

# %%
def grafico(tipo, opcao, k, premio):
    
    x = np.arange(k-30, k+30, 1)
    
    dados = pd.DataFrame(x)
    
    if tipo == 'buy' and opcao == 'call':
        dados['buy_call'] = np.where(dados[0] < k, -premio, dados[0] - k - premio)
    
    elif tipo == 'sell' and opcao == 'call':
        dados['sell_call'] = np.where(dados[0] < k, premio, k - dados[0] + premio)
        
    elif tipo == 'buy' and opcao =='put':
        dados['buy_put'] = np.where(dados[0] > k, -premio , k - dados[0] - premio)

    elif tipo == 'sell' and opcao == 'put':
        dados['sell_put'] = np.where(dados[0] > k, premio, dados[0] - k + premio)
        
    
    plt.figure(figsize = (18,9))
    plt.title('Payoff', 
              fontsize = 15)
    plt.xlim(k-30, k+30)
    plt.plot(dados[0], dados[dados.columns[1]], 'blue', linestyle = '-.', linewidth = 2)
    plt.axhline(0, color = 'black', alpha = 0.7)
    plt.axvline(k + premio, alpha = 0.5, linestyle = '--', color = 'black')
    plt.text(k + premio + 0.5, premio + 10, 'Break Even')
    plt.ylabel('Lucro')
    plt.xlabel('Preço final')
    
    return dados

# %%
grafico('buy', 'call', 103, 2)
# Out:
#       0  buy_call
# 0    73        -2
# 1    74        -2
# 2    75        -2
# 3    76        -2
# 4    77        -2
# 5    78        -2
# 6    79        -2
# 7    80        -2
# 8    81        -2
# 9    82        -2
# 10   83        -2
# 11   84        -2
# 12   85        -2
# 13   86        -2
# 14   87        -2
# 15   88        -2
# 16   89        -2
# 17   90        -2
# 18   91        -2
# 19   92        -2
# 20   93        -2
# 21   94        -2
# 22   95        -2
# 23   96        -2
# 24   97        -2
# 25   98        -2
# 26   99        -2
# 27  100        -2
# 28  101        -2
# 29  102        -2
# 30  103        -2
# 31  104        -1
# 32  105         0
# 33  106         1
# 34  107         2
# 35  108         3
# 36  109         4
# 37  110         5
# 38  111         6
# 39  112         7
# 40  113         8
# 41  114         9
# 42  115        10
# 43  116        11
# 44  117        12
# 45  118        13
# 46  119        14
# 47  120        15
# 48  121        16
# ...
